# %%
a = 5

# %%
b = 2

# %%
a + b
# Out:
# 7

# %%
name = "Shuvo"

# %%
print("Hello World")
# Out:
# Hello World

# %%
print(name)
# Out:
# Shuvo

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(name))
# Out:
# <class 'str'>

# %%
type(name)
# Out:
# str

# %%
a = "4561"

# %%
b = "12345"

# %%
a + b
# Out:
# '456112345'

# %%
int(a) + int(b)
# Out:
# 16906
