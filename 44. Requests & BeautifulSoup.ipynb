# %%
# !pip install requests
import requests
# Out:
# Requirement already satisfied: requests in c:\users\sulta\anaconda3\lib\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sulta\anaconda3\lib\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sulta\anaconda3\lib\site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sulta\anaconda3\lib\site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sulta\anaconda3\lib\site-packages (from requests) (2025.4.26)

# %%
a = requests.get("https://books.toscrape.com/")

# %%
for i in range(1, 51):
    a = requests.get(f"https://books.toscrape.com/catalogue/page-{i}.html")
    with open(f"htmls/page{i}.html", "w", encoding="utf-8") as f:
        f.write(a.text)
        print(f"Downloaded page {i} successfully")
# Out:
# Downloaded page 1 successfully
# Downloaded page 2 successfully
# Downloaded page 3 successfully
# Downloaded page 4 successfully
# Downloaded page 5 successfully
# Downloaded page 6 successfully
# Downloaded page 7 successfully
# Downloaded page 8 successfully
# Downloaded page 9 successfully
# Downloaded page 10 successfully
# Downloaded page 11 successfully
# Downloaded page 12 successfully
# Downloaded page 13 successfully
# Downloaded page 14 successfully
# Downloaded page 15 successfully
# Downloaded page 16 successfully
# Downloaded page 17 successfully
# Downloaded page 18 successfully
# Downloaded page 19 successfully
# Downloaded page 20 successfully
# Downloaded page 21 successfully
# Downloaded page 22 successfully
# Downloaded page 23 successfully
# Downloaded page 24 successfully
# Downloaded page 25 successfully
# Downloaded page 26 successfully
# Downloaded page 27 successfully
# Downloaded page 28 successfully
# Downloaded page 29 successfully
# Downloaded page 30 successfully
# Downloaded page 31 successfully
# Downloaded page 32 successfully
# Downloaded page 33 successfully
# Downloaded page 34 successfully
# Downloaded page 35 successfully
# Downloaded page 36 successfully
# Downloaded page 37 successfully
# Downloaded page 38 successfully
# Downloaded page 39 successfully
# Downloaded page 40 successfully
# Downloaded page 41 successfully
# Downloaded page 42 successfully
# Downloaded page 43 successfully
# Downloaded page 44 successfully
# Downloaded page 45 successfully
# Downloaded page 46 successfully
# Downloaded page 47 successfully
# Downloaded page 48 successfully
# Downloaded page 49 successfully
# Downloaded page 50 successfully

# %%
from bs4 import BeautifulSoup

# %%
with open("htmls/page1.html") as f:
    content = f.read()

# %%
soup = BeautifulSoup(content, "html.parser")
h3s = soup.find_all("h3")

# %%
articles = soup.select("article.product_pod")
items = []
for article in articles:
    title = article.find("h3").find("a")["title"]
    price = article.select_one("p.price_color").text.split("£")[1]
    rating_element = article.select_one("p.star-rating")
    rating = rating_element["class"][1]
    items.append({title, price, rating})

# %%
items
# Out:
# [{'51.77', 'A Light in the Attic', 'Three'},
#  {'53.74', 'One', 'Tipping the Velvet'},
#  {'50.10', 'One', 'Soumission'},
#  {'47.82', 'Four', 'Sharp Objects'},
#  {'54.23', 'Five', 'Sapiens: A Brief History of Humankind'},
#  {'22.65', 'One', 'The Requiem Red'},
#  {'33.34', 'Four', 'The Dirty Little Secrets of Getting Your Dream Job'},
#  {'17.93',
#   'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull',
#   'Three'},
#  {'22.60',
#   'Four',
#   'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics'},
#  {'52.15', 'One', 'The Black Maria'},
#  {'13.99', 'Starving Hearts (Triangular Trade Trilogy, #1)', 'Two'},
#  {'20.66', 'Four', "Shakespeare's Sonnets"},
#  {'17.46', 'Five', 'Set Me Free'},
#  {'52.29', 'Five', "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)"},
#  {'35.02', 'Five', 'Rip it Up and Start Again'},
#  {'57.25',
#   'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991',
#   'Three'},
#  {'23.88', 'Olio', 'One'},
#  {'37.59', 'Mesaerion: The Best Science Fiction Stories 1800-1849', 'One'},
#  {'51.33', 'Libertarianism for Beginners', 'Two'},
#  {'45.17', "It's Only the Himalayas", 'Two'}]

# %%
import pandas as pd

df = pd.DataFrame(items, columns=["Book Title", "Price", "Rating"])

# %%
df
# Out:
#                                            Book Title  \
# 0                                A Light in the Attic
# 1                                                 One
# 2                                                 One
# 3                                       Sharp Objects
# 4                                                Five
# 5                                     The Requiem Red
# 6                                                Four
# 7   The Coming Woman: A Novel Based on the Life of...
# 8   The Boys in the Boat: Nine Americans and Their...
# 9                                     The Black Maria
# 10                                              13.99
# 11                                              20.66
# 12                                               Five
# 13                                               Five
# 14                                               Five
# 15                                              57.25
# 16                                                One
# 17  Mesaerion: The Best Science Fiction Stories 18...
# 18                       Libertarianism for Beginners
# 19                            It's Only the Himalayas
#
#                                                 Price  \
# 0                                               51.77
# 1                                  Tipping the Velvet
# 2                                          Soumission
# 3                                               47.82
# 4                                               54.23
# 5                                                 One
# 6                                               33.34
# 7                                               Three
# 8                                               22.60
# 9                                                 One
# 10     Starving Hearts (Triangular Trade Trilogy, #1)
# 11                              Shakespeare's Sonnets
# 12                                              17.46
# 13                                              52.29
# 14                                              35.02
# 15  Our Band Could Be Your Life: Scenes from the A...
# 16                                               Olio
# 17                                                One
# 18                                                Two
# 19                                                Two
#
#                                                Rating
# 0                                               Three
# 1                                               53.74
# 2                                               50.10
# 3                                                Four
# 4               Sapiens: A Brief History of Humankind
# 5                                               22.65
# 6   The Dirty Little Secrets of Getting Your Dream...
# 7                                               17.93
# 8                                                Four
# 9                                               52.15
# 10                                                Two
# 11                                               Four
# 12                                        Set Me Free
# 13  Scott Pilgrim's Precious Little Life (Scott Pi...
# 14                          Rip it Up and Start Again
# 15                                              Three
# 16                                              23.88
# 17                                              37.59
# 18                                              51.33
# 19                                              45.17

# %%
df.to_csv("data.csv", index=False)
