# %%
name = "Shuvo"

# %%
name
# Out:
# 'Shuvo'

# %%
name.upper()
# Out:
# 'SHUVO'

# %%
name.endswith("ry")
# Out:
# False

# %%
name.endswith("vo")
# Out:
# True

# %%
name.lower()
# Out:
# 'shuvo'

# %%
name.count("S")
# Out:
# 1

# %%
s = "CodeWithHarry"
print(len(s))
# Out:
# 13

# %%
s[0:5]
# Out:
# 'CodeW'

# %%
s[1:-1]
# Out:
# 'odeWithHarr'

# %%
s[1: 12]
# Out:
# 'odeWithHarr'

# %%
s[-12:-1]
# Out:
# 'odeWithHarr'
